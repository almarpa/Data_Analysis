# %% [markdown]
# # Ejercicios 2, 3 y 4:

# %% [markdown]
# Ejercicio #2: Analiza el texto con la letra de la canción Heroes de David Bowie de 1977 (BowieHeroes.txt) para obtener una representación gráfica del vocabulario utilizado, sin tener en cuenta símbolos de puntuación ni stopwords, y la frecuencia de aparición de cada palabra.

# %%
import nltk
nltk.download('words')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
punt = ['(', ')', ',', '.', ':']
words = []
english_stops = set(stopwords.words('english'))
for linea in open('BowieHeroes.txt','r'):
    wordsLin = [word.lower() for word in word_tokenize(linea) if word not in punt and word not in english_stops]
    words = words + wordsLin

fdis2 = FreqDist(words)
#print(fdis2.plot())
fdis2.plot()
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\alex_\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.

# %% [raw]
# Ejercicio #3: Define una función para detectar palabras raras o poco frecuentes en un texto (en inglés).
# 	1. Obtener el vocabulario utilizado en el texto: palabras en minúsculas (w.isalpha)
# 	2. Obtener el conjunto de palabras del corpus nltk.corpus.words también en minúsculas (words())
# 	3. Quedarse con las palabras del primer conjunto que no estén en el segundo (difference)
# 	4. Devolver este conjunto ordenado
#
# Utiliza esta función para obtener el listado de palabras raras o poco frecuentes de los siguientes textos: BowieLetsDance.txt, nltk.corpus.nps_chat y 'shakespeare-macbeth.txt' de nltk.corpus.gutenberg.

# %%
import nltk.corpus

def unusual_words(text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    english_vocab = set(w.lower() for w in nltk.corpus.words.words())
    unusual = text_vocab - english_vocab
    return sorted(unusual)

print(unusual_words(open('BowieLetsDance.txt','r')))
print(unusual_words(nltk.corpus.nps_chat.words()))
print(unusual_words(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')))
# Out:
# []
# ['aaaaaaaaaaaaaaaaa', 'aaahhhh', 'abortions', 'abou', 'abourted', 'abs', 'ack', 'acros', 'actualy', 'adams', 'adds', 'adduser', 'adjusts', 'adoted', 'adreniline', 'ads', 'adults', 'afe', 'affairs', 'affari', 'affects', 'afk', 'agaibn', 'ages', 'aggravated', 'agurlwithbigguns', 'ahah', 'ahahah', 'ahahh', 'ahahha', 'ahh', 'ahhah', 'ahhahahaha', 'ahhh', 'ahhhh', 'ahhhhhh', 'ahhhhhhhhhhhhhh', 'aiiiiiiiiiiiiiiiiiiiiiiii', 'aiken', 'aime', 'akdt', 'akon', 'akron', 'akst', 'aligator', 'allergies', 'allo', 'allowed', 'aloha', 'alohaaa', 'alohas', 'alot', 'alotta', 'alternatives', 'alterz', 'alwys', 'alzheimers', 'amazingness', 'americans', 'anithing', 'ans', 'answering', 'answers', 'antidepressants', 'anygirl', 'anymore', 'anythin', 'anytime', 'anyyyyyyyyyyyyyyyyy', 'aok', 'apoligize', 'appearently', 'appears', 'applaudes', 'appleton', 'appologise', 'appologize', 'aqwesome', 'arggghhh', 'argh', 'armtnpeat', 'arrested', 'arrived', 'arround', 'asked', 'askin', 'asking', 'asks', 'asl', 'asnwer', 'asses', 'asshole', 'assholes', 'asss', 'assumes', 'aterry', 'atl', 'attempted', 'attracted', 'aussies', 'awesomee', 'awesomes', 'awrighty', 'awsome', 'aww', 'awww', 'awwww', 'awwwwww', 'awwwwwww', 'awwwwwwwwww', 'aynawy', 'az', 'azerbaijan', 'baaaaalllllllliiiiiiinnnnnnnnnnn', 'babay', 'babblein', 'babes', 'babies', 'babiess', 'babycakeses', 'bachelorette', 'backatchya', 'backfrontsidewaysandallaroundtheworld', 'backroom', 'bacl', 'bagels', 'bahahahaa', 'bak', 'balad', 'balck', 'ballin', 'balls', 'bandito', 'bandsaw', 
 'anticipat', 'appalls', 'appar', 'apparation', 'appeare', 'appeares', 'approaches', 'approch', 'approches', 'approue', 'arabia', 'arme', 'armes', 'armour', 'aroynt', 'arriu', 'artificiall', 'aske', 'asleepe', 'assaileable', 'assisted', 'attendants', 'attyre', 'auant', 'auarice', 'auaricious', 'augure', 'augures', 'auoid', 'auouch', 'auouches', 'auoyded', 'authoriz', 'awak', 'ayd', 'ayde', 'ayme', 'ayre', 'babes', 'baboones', 'backe', 'backs', 'badg', 'baited', 'balles', 'balme', 'bals', 'banke', 'banners', 'banq', 'banquets', 'banquo', 'banquoh', 'barke', 'barlet', 'battaile', 'battell', 'battlements', 'beards', 'beare', 'beares', 'beate', 'became', 'beds', 'beene', 'befor', 'began', 'begge', 'begger', 'behinde', 'beldams', 'beleefe', 'beleeu', 'beleeue', 'belzebub', 'benyson', 'bestowes', 'betweene', 'bides', 'bids', 'binde', 'birds', 'birnan', 'birnane', 'birthdome', 'blacke', 'blames', 'blaspheming', 'bleeds', 'blesse', 'blessings', 'blinde', 'blisters', 'bloodie', 'bloodier', 'blowes', 'blowne', 'boadments', 'bonelesse', 'bones', 'booke', 'borrowed', 'bosome', 'bosomes', 'botches', 'bottome', 'boue', 'boughes', 'boundlesse', 'boyle', 'braine', 'braines', 'brandisht', 'braue', 'brauely', 'breake', 'breefe', 'brest', 'brests', 'bridegroome', 'briefely', 'brightest', 'brinded', 'brings', 'browes', 'brows', 'broyle', 'bruited', 'bubbles', 'buffets', 'buriall', 'burne', 'businesse', 'buttrice', 'byrnam', 'byrnan', 'byrnane', 'calls', 'cancell', 'candles', 'cannons', 'canst', 'capitall', 'caps', 'captaine', 'captaines', 'captiuitie', 'carelesse', 'carowsing', 'caru', 'cases', 'castles', 'cath', 'cathnes', 'cauldron', 'causes', 'cawdor', 'cawdron', 'celebrates', 'censures', 'centinell', 'certaine', 'cesterne', 'chafes', 'challice', 'chamberlaines', 'chambers', 'chanc', 'charg', 'charme', 'charmed', 'charmes', 'charnell', 'chawdron', 'cheapely', 'cheefest', 'cheekes', 'cheere', 'chestnuts', 'chickens', 'chiefe', 'children', 'childrens', 'chimneys', 'choake', 'choppie', 'chops', 'choughes', 'christendome', 'churches', 'cines', 'clayme', 'cleane', 'cleare', 'clearenesse', 'cleares', 'cleaue', 'cleere', 'climbe', 'clogges', 'clos', 'closset', 'clowd', 'clowdy', 'cloyster', 'coigne', 'colmekill', 'colmes', 'colours', 'com', 'combin', 'comforted', 'commanded', 'commands', 'commencing', 'commendations', 'commends', 'comming', 'committed', 'companie', 'companions', 'compar', 'comparisons', 'compast', 'compell', 'composd', 'compt', 'conceiue', 'concerne', 'concluded', 'condemne', 'confin', 'confinelesse', 'confirme', 'confounds', 'confronted', 'confus', 'coniure', 'consequences', 'conspirers', 'constancie', 'contend', 'contriuer', 'conuert', 'conuey', 'conuince', 'conuinces', 'coole', 'cooz', 'coppie', 'corne', 'corporall', 'cosin', 'cosins', 'coueted', 'councell', 'counsail', 'counsailers', 'countrey', 'countreyes', 'countries', 'courst', 'cousins', 'cozens', 'cracke', 'cracks', 'craue', 'craues', 'crauing', 'craz', 'creepes', 'crests', 'crickets', 'cries', 'croakes', 'crost', 'crowne', 'crownes', 'cruell', 'crueltie', 'cryes', 'cumberland', 'cures', 'curres', 'curriors', 'curses', 'custome', 'daintie', 'dames', 'damne', 'darefull', 'darke', 'darknesse', 'dasht', 'daughters', 'dauntlesse', 'dayes', 'deadmans', 'deafe', 'deaftly', 'deale', 'deare', 'dearest', 'deaths', 'deceitfull', 'deceiue', 'deedes', 'deeds', 'deepe', 'deepely', 'deeper', 'deepest', 'deere', 'deerest', 'degrees', 'deigne', 'delights', 'delinquents', 'deliuer', 'deliuers', 'demerits', 'denies', 'desart', 'descended', 'descends', 'deser ...

# %% [markdown]
# Ejercicio #4: Analiza el texto Moby Dick de Herman Melville 1851, que está en el corpus gutenberg (melville-moby_dyck.txt), utilizando tokenizer, stopwords y stemmer y sin considerar simbolos de puntuación. En concreto:
# ¿Cuántas palabras que no sean signos de puntuación ni stopwords tiene?
# ¿Cuál es el stem mas frecuente?
# ¿Cuántos stems aparecen una sola vez
# ¿Cuáles son los 50 stems más frecuentes y cuál es su frecuencia? Represéntalas gráficamente

# %%
from nltk.corpus import gutenberg, stopwords
from nltk.probability import FreqDist
from nltk import PorterStemmer
from nltk.tokenize import word_tokenize

english_stop = stopwords.words('english')
##words = gutenberg.words('melville-moby_dick.txt')
punt = ['(', ')', ',', '.', ':','[',']','-','--',';','!','?','\"','\'','\`','\'\'', '``']
words = []
frases = gutenberg.sents('melville-moby_dick.txt')
for f in frases:
#    print(str(f))
    for w in word_tokenize(''.join(f)):
        if w not in punt and w.lower() not in english_stop:
            words.append(w.lower())
vocab = set(words)
   
stemmer = PorterStemmer()
stems = []
for word in words:
    stems.append(stemmer.stem(word))
    
vocabStems = set(stems)
### ¿Cuántos stems distintos aparecen?
print("No de stems diferentes = ", len(vocabStems))

## ¿Cuántas palabras y frases tiene?
print("No de frases = ", len(frases))
print("No de palabras = ", len(words))
print("No de palabras distintas = ", len(vocab))

fdist = FreqDist(stems)
## ¿Cuál es el stem mas frecuente?
print("Stem mas frecuente = ", fdist.max())

##¿Cuantos stems aparecen una sola vez?
print("Numero de stems que aparecen una sola vez = ", len(fdist.hapaxes()))

##¿Cuáles son los 50 stems más frecuentes y cuál es su frecuencia?
print("Listado de los 50 stems más comunes y sus frecuencias")
print(fdist.most_common(50)) # fdist.pprint(50)
fdist.plot(50)
# Out:
# No de stems diferentes =  30004
# No de frases =  10059
# No de palabras =  34237
# No de palabras distintas =  30110
# Stem mas frecuente =  sir
# Numero de stems que aparecen una sola vez =  28903
# Listado de los 50 stems más comunes y sus frecuencias
# [('sir', 157), ('aye', 143), ('oh', 138), ('ye', 69), ("'s", 68), ('well', 60), ('isay', 54), ('queequeg', 50), ('inde', 47), ('saidi', 44), ('men', 42), ('man', 41), ('though', 38), ('cook', 37), ('boy', 37), ('nevertheless', 35), ('yet', 35), ('thati', 34), ('ha', 34), ('howev', 33), ('gentlemen', 32), ('stubb', 32), ('flask', 32), ('starbuck', 30), ('therefor', 30), ('perhap', 29), ('besid', 28), ('criedahab', 26), ('mr.starbuck', 26), ('shipmat', 25), ('ahab', 25), ('pip', 23), ('ah', 22), ('nay', 22), ('eh', 19), ('captainahab', 19), ('thoughti', 19), ('bildad', 19), ('andthen', 18), ('criedstubb', 18), ('saidstubb', 17), ('pull', 17), ('meantim', 16), ('come', 16), ('*', 16), ('atleast', 16), ('asitwer', 15), ('criedstarbuck', 15), ('oldman', 14), ('landlord', 14)]
