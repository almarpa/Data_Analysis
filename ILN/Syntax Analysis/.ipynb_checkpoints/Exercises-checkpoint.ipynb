# %%
import nltk
nltk.app.rdparser()
# Out:
# [('under',)]
# [('with',)]
# [('in',)]
# [('under',), ('with',)]
# [('ate',)]
# [('saw',)]
# [('dog',)]
# [('telescope',)]
# [('park',)]
# [('dog',), ('telescope',)]
# [('man',)]
# [('park',), ('dog',), ('telescope',)]
# [('the',)]
# [('a',)]
# [(V, NP)]
# [(V,)]
# [(V, NP, PP)]
# [(V, NP), (V,)]
# [(Det, N, PP)]
# [(Det, N)]
# S [(NP, VP)]
# NP [(Det, N, PP), (Det, N)]
# VP [(V, NP, PP), (V, NP), (V,)]
# PP [(P, NP)]
# NP [('I',)]
# Det [('the',), ('a',)]
# N [('man',), ('park',), ('dog',), ('telescope',)]
# V [('ate',), ('saw',)]
# P [('in',), ('under',), ('with',)]
# [('Andalucía',)]
# [('Mediterráneo',)]
# [('País_vasco',)]
# [('Andalucía',), ('Mediterráneo',)]
# [('Ebro',)]
# [('País_vasco',), ('Andalucía',), ('Mediterráneo',)]
# [('valenciana',)]
# [('gallega',)]
# [('río',)]
# [('ríos',)]
# [('mares',)]
# [('río',), ('ríos',)]
# [('mar',)]
# [('mares',), ('río',), ('ríos',)]
# [('comunidad',)]
# [('mar',), ('mares',), ('río',), ('ríos',)]
# [('Qué',)]
# [('Cuántos',)]
# ...

# %% [markdown]
# Ejercicio 1. Escribe la secuencia de derivación por la izquierda de la oración ¿ Qué mares bañan Andalucía ?
# Recuerda que el símbolo inicial de la gramática es el símbolo S. Derivar por la izquierda significa que siempre se expande el no terminal más a la izquierda en la cadena de derivación.

# %% [markdown]
# Ejercicio 2. Dibuja el árbol sintáctico correspondiente al análisis de la oración anterior según la gramática dada.

# %% [markdown]
# Ejercicio 3. Escribe en notación parentizada el análisis sintáctico equivalente al árbol sintáctico anterior.

# %% [markdown]
# Ejercicio 6. Utiliza la app nltk.app.rdparser() para observar la estrategia que sigue un analizador descendente recursivo. Sustituye la gramática por defecto por la gramática proporcionada, y analiza la oración ¿ Qué mares bañan Andalucía ? .

# %% [markdown]
# Ejercicio 7. Modifica la gramática añadiendo la siguiente regla NOMINAL  -> NOMINAL NC. Vuelve a analizar la oración anterior y observa qué ocurre.
# ((En el ejercicio 7 se ha añadido la regla NOMINAL -> NOMINAL NC, ¿qué ha ocurrido durante la ejecución del analizador sintáctico descendente recursivo? ¿Por qué ocurre? ¿Sabes cómo se llaman a las gramáticas que tienen esta particularidad?))

# %% [markdown]
# Ejercicio 8. Ahora vas a observar una estrategia de análisis ascendente, shift-reduce, utilizando la app nltk.app.srparser(). Al igual que hiciste en el Ejercicio 6 sustituye la gramática por defecto por la gramática proporcionada, y analiza la oración ¿ Qué mares bañan Andalucía ? .  Tendrás que tomar algunas decisiones (desplazar o reducir) para conseguir analizar la oración.

# %% [markdown]
# Ejercicio 9. Repite el Ejercicio 7 con el analizador shift-reduce y observa qué ocurre.
